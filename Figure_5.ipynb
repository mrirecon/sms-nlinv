# %% [markdown]
# # bash

# %%
bart version
# Out:
# v0.4.04

# %%
cd ../Figure_5
sh MB1_top.sh
# Out:
# Scaling: 9264.554232

# %%
bart transpose 0 1 MB1_top tmp
bart toimg tmp tmp.png
cat tmp.png | display
# Out:
# Writing 1 image(s)...done.

# %%
sh MB1_bottom.sh
# Out:
# Scaling: 9092.532702

# %%
bart transpose 0 1 MB1_bottom tmp
bart toimg tmp tmp.png
cat tmp.png | display
# Out:
# Writing 1 image(s)...done.

# %%
sh MB2_aligned.sh
# Out:
# SMS-NLINV reconstruction. Multiband factor: 2
# Scaling: 8566.767121

# %%
bart reshape $(bart bitmask 1 13) $((2 * 192)) 1 MB2_aligned tmp1
bart transpose 0 1 tmp1 tmp
bart toimg tmp tmp.png
cat tmp.png | display
# Out:
# Writing 1 image(s)...done.

# %%
sh MB2_caipi.sh
# Out:
# SMS-NLINV reconstruction. Multiband factor: 2
# Scaling: 8559.532398

# %%
bart reshape $(bart bitmask 1 13) $((2 * 192)) 1 MB2_caipi tmp1
bart transpose 0 1 tmp1 tmp
bart toimg tmp tmp.png
cat tmp.png | display
# Out:
# Writing 1 image(s)...done.

# %%
sh MB3_aligned.sh
# Out:
# SMS-NLINV reconstruction. Multiband factor: 3
# Scaling: 7863.063489

# %%
bart slice 13 0 MB3_aligned tmp0
bart slice 13 2 MB3_aligned tmp1
bart join 1 tmp0 tmp1 tmp2
bart transpose 0 1 tmp2 tmp
bart toimg tmp tmp.png
cat tmp.png | display
# Out:
# Writing 1 image(s)...done.

# %%
sh MB3_caipi.sh
# Out:
# SMS-NLINV reconstruction. Multiband factor: 3
# Scaling: 7861.781780

# %%
bart slice 13 0 MB3_caipi tmp0
bart slice 13 2 MB3_caipi tmp1
bart join 1 tmp0 tmp1 tmp2
bart transpose 0 1 tmp2 tmp
bart toimg tmp tmp.png
cat tmp.png | display
# Out:
# Writing 1 image(s)...done.
