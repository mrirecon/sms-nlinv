# %% [markdown]
# # bash

# %%
bart version
# Out:
# v0.4.04

# %%
cd Figure_4
sh Fig4a.sh
# Out:
# Done.
# Done.
# Done.
# Done.
# Size: 147456 Samples: 147456 Acc: 1.00
# Maximum eigenvalue: 1.00e+00
# l2 regularization: 0.010000
# conjugate gradients
# Total Time: 13.208595
# Size: 147456 Samples: 43775 Acc: 3.37
# Maximum eigenvalue: 1.00e+00
# l2 regularization: 0.010000
# conjugate gradients
# Total Time: 22.291683
# SMS-NLINV reconstruction. Multiband factor: 2
# Scaling: 7388.113522
# SMS-NLINV reconstruction. Multiband factor: 2
# Scaling: 8492.214902

# %%
bart transpose 0 1 ESPIRiT_4a tmp1
bart transpose 1 2 tmp1 tmp
bart reshape $(bart bitmask 0 1 2 4) $((2 * 192)) $((2 * 192)) 1 1 tmp tmp1
bart toimg tmp1 tmp.png
cat tmp.png | display
# Out:
# Writing 1 image(s)...done.

# %%
bart transpose 1 4 SMSNLINV_4a tmp
bart reshape $(bart bitmask 0 1 4 13) $((192 * 2)) $((192 * 2)) 1 1 tmp tmp1
bart transpose 0 1 tmp1 tmp
bart toimg tmp tmp.png
cat tmp.png | display
# Out:
# Writing 1 image(s)...done.

# %%
sh Fig4b.sh
# Out:
# Done.
# Done.
# Done.
# Done.
# Size: 147456 Samples: 147456 Acc: 1.00
# Maximum eigenvalue: 1.00e+00
# l2 regularization: 0.010000
# conjugate gradients
# Total Time: 18.409483
# Size: 147456 Samples: 39168 Acc: 3.76
# Maximum eigenvalue: 1.00e+00
# l2 regularization: 0.010000
# conjugate gradients
# Total Time: 38.358111
# SMS-NLINV reconstruction. Multiband factor: 2
# Scaling: 7388.113522
# SMS-NLINV reconstruction. Multiband factor: 2
# Scaling: 9145.600220

# %%
bart transpose 0 1 ESPIRiT_4b tmp1
bart transpose 1 2 tmp1 tmp
bart reshape $(bart bitmask 0 1 2 4) $((2 * 192)) $((2 * 192)) 1 1 tmp tmp1
bart toimg tmp1 tmp.png
cat tmp.png | display
# Out:
# Writing 1 image(s)...done.

# %%
bart transpose 1 4 SMSNLINV_4b tmp
bart reshape $(bart bitmask 0 1 4 13) $((192 * 2)) $((192 * 2)) 1 1 tmp tmp1
bart transpose 0 1 tmp1 tmp
bart toimg tmp tmp.png
cat tmp.png | display
# Out:
# Writing 1 image(s)...done.
